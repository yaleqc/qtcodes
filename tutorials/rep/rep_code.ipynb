# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0, "../../")
from topological_codes import RepetitionQubit
from qiskit import execute, Aer

# %%
qubit = RepetitionQubit({"d":3})
qubit.stabilize()
qubit.stabilize()
# qubit.logical_x()
qubit.readout_z()

# %%
qubit.draw(output='mpl', fold=150)

# %%
execute(qubit, Aer.get_backend('qasm_simulator')).result().get_counts()
